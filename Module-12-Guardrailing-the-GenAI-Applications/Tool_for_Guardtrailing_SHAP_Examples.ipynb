# %% [markdown]
# # **SHAP**
# (SHapley Additive exPlanations) is a theoretic approach to explain the output of any machine learning model.

# %% [markdown]
# # **Example 1: Text-Generation**
# We will write a piece of text and let the model predict the following text. with plot we will see how model prediction is done.

# %%
# install transformers and shap packages
# !pip install transformers shap
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.1.4)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import shap

# %%
# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model = AutoModelForCausalLM.from_pretrained("gpt2")

# %%
# set model decoder to true
model.config.is_decoder = True
# set text-generation params under task_specific_params
model.config.task_specific_params["text-generation"] = {
    "do_sample": True,
    "max_length": 50,
    "temperature": 0.7,
    "top_k": 50,
    "no_repeat_ngram_size": 2,
}

# %%
# Input
sentence = ["Once upon a time, in a cozy little house,"]

# %%
# Call PartitionExplainer as a default Explainer
explainer = shap.Explainer(model, tokenizer)
# Apply input to generate shap values
shap_values_text_gen = explainer(sentence)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 0/110 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:24, 24.06s/it]

# %% [markdown]
# **SHAP values provide a way to interpret the output of machine learning models. For text models, SHAP values explain how each word or token in the input text contributes to the prediction of the model.**

# %%
# Generate plot
shap.plots.text(shap_values_text_gen)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_dpgewbenfkkihxhqmwfx = '_tp_dpgewbenfkkihxhqmwfx_output_0';
#     document._zoom_dpgewbenfkkihxhqmwfx = undefined;
#     function _output_onclick_dpgewbenfkkihxhqmwfx(i) {
#         var next_id = undefined;
#
#         if (document._zoom_dpgewbenfkkihxhqmwfx !== undefined) {
#             document.getElementById(document._zoom_dpgewbenfkkihxhqmwfx+ '_zoom').style.display = 'none';
#
#             if (document._zoom_dpgewbenfkkihxhqmwfx === '_tp_dpgewbenfkkihxhqmwfx_output_' + i) {
#                 document.getElementById(document._zoom_dpgewbenfkkihxhqmwfx).style.display = 'block';
#                 document.getElementById(document._zoom_dpgewbenfkkihxhqmwfx+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_dpgewbenfkkihxhqmwfx).style.display = 'none';
#                 document.getElementById(document._zoom_dpgewbenfkkihxhqmwfx+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_dpgewbenfkkihxhqmwfx !== '_tp_dpgewbenfkkihxhqmwfx_output_' + i) {
#             next_id = '_tp_dpgewbenfkkihxhqmwfx_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_dpgewbenfkkihxhqmwfx = next_id;
#     }
#     function _output_onmouseover_dpgewbenfkkihxhqmwfx(i, el) {
#         if (document._zoom_dpgewbenfkkihxhqmwfx !== undefined) { return; }
#         if (document._hover_dpgewbenfkkihxhqmwfx !== undefined) {
#             document.getElementById(document._hover_dpgewbenfkkihxhqmwfx + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_dpgewbenfkkihxhqmwfx).style.display = 'none';
#         }
#         document.getElementById('_tp_dpgewbenfkkihxhqmwfx_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_dpgewbenfkkihxhqmwfx = '_tp_dpgewbenfkkihxhqmwfx_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.4087938205585264); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_0_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(0)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(0, this);">I</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.36149732620320846); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_1_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(1)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(1, this);">was</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5506833036244801); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_2_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(2)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(2, this);">a</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.3851455733808674); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_3_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(3)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(3, this);">little</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5033868092691621); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_4_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(4)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(4, this);">bit</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.527035056446821); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_5_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(5)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(5, this);">of</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.219607843137255); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_6_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(6)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(6, this);">a</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5900970489205783); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_7_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(7)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(7, this);">recl</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_dpgewbenfkkihxhqmwfx_output_8_name"
#     onclick="_output_onclick_dpgewbenfkkihxhqmwfx(8)"
#     onmouseover="_output_onmouseover_dpgewbenfkkihxhqmwfx(8, this);">use</div><br><br><div id='_tp_dpgewbenfkkihxhqmwfx_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="48.94672498284444%" y1="33" x2="48.94672498284444%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="48.94672498284444%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="34.24870585666515%" y1="33" x2="34.24870585666515%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.24870585666515%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="19.55068673048585%" y1="33" x2="19.55068673048585%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.55068673048585%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="63.64474410902373%" y1="33" x2="63.64474410902373%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.64474410902373%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="78.34276323520304%" y1="33" x2="78.34276323520304%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="78.34276323520304%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">4</text><line x1="15.477623768012265%" y1="33" x2="15.477623768012265%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="15.477623768012265%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-4.55423</text><text x="15.477623768012265%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4.55423</text><text x="15.477623768012265%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="31.1268863606338%" y1="33" x2="31.1268863606338%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="31.1268863606338%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-2.42479</text><text x="31.1268863606338%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-2.42479</text><text x="31.1268863606338%" y="10" font-size="12px" fill="rgb(120,120,120)" d

# %% [markdown]
# In the context of text generation models like GPT-2, the plot shows which tokens (words) in the input text have the most influence on the model’s generated text.

# %% [markdown]
# # **Plot Explanation**
# **Base Value:**
# It ia a Starting point of prediction. It represents the average prediction of the model before considering the specific input tokens.
#
# **SHAP values:** It helps to explain why the model gave a certain output by showing the impact of each input token on the prediction.
#
# **Tokens Contribution:**
# The plot is displaying the input tokens along with their corresponding SHAP values.Positive SHAP values indicate that a token contributes positively towards the model's prediction. It will Push the prediction up/down from the base as per possitive/negetive value.
#
# **Text Highlights:**
# In the plot, tokens with higher SHAP values are highlighted red colors to indicate their importance towards positive influence on the prediction. while the blue color indicates negative contribution and the intensity of the color shows its strength in the respective direction.
#
# Click on each token from the output-text to see the influence of input tokens.

# %% [markdown]
# # **Example 2: Emotion Classifier**
# We will provide a text and model will classify the emotions like
# sadness, joy, love, anger, fear, surprise as our model is trained for this emotions.

# %%
#Emotion Classifier
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import shap

# %%
# load the model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion", use_fast=True)
model = AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion")

# %%
#create a pipeline to use the model
pred = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    device=-1,  # Use -1 to indicate CPU
)

# %%
# function to analyse the text using model and create explainer using SHAP
def analyze_text(texts):
    # Create SHAP explainer
    explainer = shap.Explainer(pred)
    # Generate SHAP values
    shap_values = explainer(texts)
    # Create and show the SHAP plot
    shap.plots.text(shap_values)

# %%
 # Text Input from the user
 user_input = input("Enter the text you want to analyze: ")
analyze_text([user_input])
# Out:
# Enter the text you want to analyze: I'm furious that they canceled the event without any notice or explanation
#   0%|          | 0/240 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:29, 29.14s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_jnsdzzcmfmavxlmqiojr = '_tp_jnsdzzcmfmavxlmqiojr_output_0';
#     document._zoom_jnsdzzcmfmavxlmqiojr = undefined;
#     function _output_onclick_jnsdzzcmfmavxlmqiojr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_jnsdzzcmfmavxlmqiojr !== undefined) {
#             document.getElementById(document._zoom_jnsdzzcmfmavxlmqiojr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_jnsdzzcmfmavxlmqiojr === '_tp_jnsdzzcmfmavxlmqiojr_output_' + i) {
#                 document.getElementById(document._zoom_jnsdzzcmfmavxlmqiojr).style.display = 'block';
#                 document.getElementById(document._zoom_jnsdzzcmfmavxlmqiojr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_jnsdzzcmfmavxlmqiojr).style.display = 'none';
#                 document.getElementById(document._zoom_jnsdzzcmfmavxlmqiojr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_jnsdzzcmfmavxlmqiojr !== '_tp_jnsdzzcmfmavxlmqiojr_output_' + i) {
#             next_id = '_tp_jnsdzzcmfmavxlmqiojr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_jnsdzzcmfmavxlmqiojr = next_id;
#     }
#     function _output_onmouseover_jnsdzzcmfmavxlmqiojr(i, el) {
#         if (document._zoom_jnsdzzcmfmavxlmqiojr !== undefined) { return; }
#         if (document._hover_jnsdzzcmfmavxlmqiojr !== undefined) {
#             document.getElementById(document._hover_jnsdzzcmfmavxlmqiojr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_jnsdzzcmfmavxlmqiojr).style.display = 'none';
#         }
#         document.getElementById('_tp_jnsdzzcmfmavxlmqiojr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_jnsdzzcmfmavxlmqiojr = '_tp_jnsdzzcmfmavxlmqiojr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_0_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(0)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(0, this);">sadness</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_1_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(1)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(1, this);">joy</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_2_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(2)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(2, this);">love</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_3_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(3)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(3, this);">anger</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_4_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(4)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(4, this);">fear</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_jnsdzzcmfmavxlmqiojr_output_5_name"
#     onclick="_output_onclick_jnsdzzcmfmavxlmqiojr(5)"
#     onmouseover="_output_onmouseover_jnsdzzcmfmavxlmqiojr(5, this);">surprise</div><br><br><div id='_tp_jnsdzzcmfmavxlmqiojr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.71785944265388%" y1="33" x2="49.71785944265388%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.71785944265388%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.91654458903092%" y1="33" x2="34.91654458903092%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.91654458903092%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="20.115229735407954%" y1="33" x2="20.115229735407954%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.115229735407954%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="64.51917429627683%" y1="33" x2="64.51917429627683%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.51917429627683%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="79.32048914989981%" y1="33" x2="79.32048914989981%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.32048914989981%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="12.714572308596471%" y1="33" x2="12.714572308596471%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.714572308596471%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="12.714572308596471%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="12.714572308596471%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="12.714572308596471%" y1="33" x2="12.714572308596471%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.714572308596471%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="12.714572308596471%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="12.714572308596471%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">sadness</tspan>(inputs)</text><rect x="12.714572308596471%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="12.714572308596471%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="12.714572308596471%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="12.714572308596471%" width="-0.0%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="t

# %% [markdown]
# # **Plot Explanation:**
#
# **Base Value:** The base value is the average prediction score across the dataset or a baseline prediction. It represents the model’s default or expected prediction before any specific tokens are considered.
#
# **Input Tokens:** The tokens are the individual words or subwords from the input text that were tokenized by the tokenizer.
#
# **SHAP Values:** It indicate how each token affects the model’s output prediction. These values are calculated based on how the model's prediction changes when each token is included or excluded.
#
# Click on each input token to understand the impact of the higher shap values on the emotion classification.
